# %% [markdown]
# # Buck

# %%
import matplotlib.pyplot as plt

# Definindo o tamanho da figura e os subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 2.5), gridspec_kw={'hspace': 0.5})

linewidth = 2.

x = [.1, .2, .3, .4, .5, .6, .7, .8, .9, 1.]

y1 = [1.633e-05, 1.606e-05, 1.062e-05,
      8.258e-06, 7.677e-06, 4.628e-06, 2.251e-06, 8.239e-07, 1.000e-06, 8.333e-08]

y2 = [1.620e-05, 1.603e-05, 1.064e-05,
      8.274e-06, 7.639e-06, 4.621e-06, 2.250e-06, 8.243e-07, 1.000e-06, 8.333e-08]


line1, = axs[0].plot(x, y1,
                     linestyle='-', color='#120a8f', linewidth=linewidth, alpha=1)
line2, = axs[0].plot(x, y2, linestyle='-',
                     color='#8b0000', label='Linearizado', linewidth=linewidth)
axs[0].set_xlabel(r'$\rho$', fontsize=18)
axs[0].set_ylabel('Média dos ITEE (s)', fontsize=16)
axs[0].grid(linestyle='--')
axs[0].set_title('ETM Estático', fontsize=20)
axs[0].tick_params(axis='both', direction='in', length=4, width=1,
                   colors='black', top=True, right=True, labelsize=16)
# Definindo a notação científica para os eixos y
axs[0].ticklabel_format(axis='y', style='sci', scilimits=(-3, 3))


y1 = [1.022e-04, 8.109e-05, 5.459e-05,
      4.279e-05, 5.829e-05, 3.651e-05, 1.608e-05, 3.668e-06, 9.673e-07, 5.530e-08]

y2 = [1.008e-04, 8.170e-05, 5.419e-05,
      4.251e-05, 5.851e-05, 3.650e-05, 1.637e-05, 3.819e-06, 9.865e-07, 5.530e-08]

line1, = axs[1].plot(x, y1,
                     linestyle='-', color='#120a8f', linewidth=linewidth, alpha=1)
line2, = axs[1].plot(x, y2, linestyle='-',
                     color='#8b0000', label='Linearizado', linewidth=linewidth)


axs[1].set_xlabel(r'$\rho$', fontsize=18)
axs[1].set_ylabel('Média dos ITEE (s)', fontsize=16)

axs[1].grid(linestyle='--')
axs[1].set_title('ETM Dinâmico', fontsize=20)
axs[1].tick_params(axis='both', direction='in', length=4, width=1,
                   colors='black', top=True, right=True, labelsize=16)
# Definindo a notação científica para os eixos y
axs[1].ticklabel_format(axis='y', style='sci', scilimits=(-3, 3))


fig.legend([line1, line2], ['Não Linear', 'Linearizado'],
           fontsize=14, loc='upper center', bbox_to_anchor=(.5, 1.3), fancybox=False, shadow=False, ncol=2)

plt.tight_layout()

plt.savefig(
    '/home/andel/Projetos/Latex/[TCC] Andevaldo Vitório/figuras/buck/itee-mean.eps', format='eps', bbox_inches='tight')
# Out:
# /tmp/ipykernel_124925/1591718153.py:57: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Definindo o tamanho da figura e os subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 3.3))

linewidth = 2.

x = [.1, .2, .3, .4, .5, .6, .7, .8, .9, 1.]

y1 = [6.434e-03, 6.907e-03, 6.906e-03,
      6.921e-03, 6.921e-03, 3.377e-03, 3.261e-03, 3.261e-03, 6.909e-03, 3.341e-02]

y2 = [6.358e-03, 6.860e-03, 6.859e-03,
      6.875e-03, 6.875e-03, 3.324e-03, 3.213e-03, 3.213e-03, 6.864e-03, 3.330e-02]


# Tensão Não Linear
line1, = axs[0].plot(x, y1,
                     linestyle='-', color='#120a8f', linewidth=linewidth, alpha=1)
line2, = axs[0].plot(x, y2, linestyle='-',
                     color='#8b0000', label='Linearizado', linewidth=linewidth)
axs[0].set_xlabel(r'$\rho$', fontsize=18)
axs[0].set_ylabel('$t_{\mathrm{s}}$ (s)', fontsize=18)
axs[0].grid(linestyle='--')
axs[0].set_title('ETM Estático', fontsize=20)
axs[0].tick_params(axis='both', direction='in', length=4, width=1,
                   colors='black', top=True, right=True, labelsize=16)
# axs[0].ticklabel_format(style='plain')


y1 = [6.434e-03, 6.906e-03, 6.906e-03,
      6.921e-03, 3.354e-03, 3.377e-03, 3.261e-03, 3.261e-03, 6.909e-03, 3.341e-02]

y2 = [6.357e-03, 6.860e-03, 6.859e-03,
      6.875e-03, 3.302e-03, 3.324e-03, 3.213e-03, 3.213e-03, 6.864e-03, 3.330e-02]


line1, = axs[1].plot(x, y1,
                     linestyle='-', color='#120a8f', linewidth=linewidth, alpha=1)
line2, = axs[1].plot(x, y2, linestyle='-',
                     color='#8b0000', label='Linearizado', linewidth=linewidth)


axs[1].set_xlabel(r'$\rho$', fontsize=18)
axs[1].set_ylabel('$t_{\mathrm{s}}$ (s)', fontsize=18)

axs[1].grid(linestyle='--')
axs[1].set_title('ETM Dinâmico', fontsize=20)
axs[1].tick_params(axis='both', direction='in', length=4, width=1,
                   colors='black', top=True, right=True, labelsize=16)
# axs[1].ticklabel_format(style='plain')


# fig.legend([line1, line2], ['Não Linear', 'Linearizado'],
#            fontsize=18, loc='upper center', bbox_to_anchor=(.5, 0.0), fancybox=False, shadow=False, ncol=2)

plt.tight_layout()

plt.savefig(
    '/home/andel/Projetos/Latex/[TCC] Andevaldo Vitório/figuras/buck/ts.eps', format='eps', bbox_inches='tight')

# %% [markdown]
# # Boost

# %%
# Definindo o tamanho da figura e os subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 2.5), gridspec_kw={'hspace': 0.5})

linewidth = 2.

x = [.1, .2, .3, .4, .5, .6, .7, .8, .9, 1.]

y1 = [1.201e-04, 3.341e-05, 4.086e-05,
      2.877e-05, 2.409e-05, 1.917e-05, 7.551e-06, 2.154e-06, 1.220e-06, 6.632e-07]

y2 = [6.370e-05, 2.684e-05,  3.944e-05,
      3.202e-05, 1.708e-05, 1.847e-05, 8.886e-06, 2.535e-06, 1.250e-06, 5.525e-07]


line1, = axs[0].plot(x, y1,
                     linestyle='-', color='#120a8f', linewidth=linewidth, alpha=1)
line2, = axs[0].plot(x, y2, linestyle='-',
                     color='#8b0000', label='Linearizado', linewidth=linewidth)
axs[0].set_xlabel(r'$\rho$', fontsize=18)
axs[0].set_ylabel('Média dos ITEE (s)', fontsize=16)
axs[0].grid(linestyle='--')
axs[0].set_title('ETM Estático', fontsize=20)
axs[0].tick_params(axis='both', direction='in', length=4, width=1,
                   colors='black', top=True, right=True, labelsize=16)
# Definindo a notação científica para os eixos y
axs[0].ticklabel_format(axis='y', style='sci', scilimits=(-3, 3))


y1 = [1.871e-04, 5.271e-05, 6.690e-05, 4.652e-05,
      3.545e-05, 2.562e-05, 1.105e-05,  8.044e-07, 6.701e-07, 6.632e-07]

y2 = [6.008e-04, 6.027e-04, 5.243e-04, 4.891e-04,
      4.320e-04, 3.964e-04, 2.529e-04, 5.578e-07, 5.696e-07, 5.525e-07]

line1, = axs[1].plot(x, y1,
                     linestyle='-', color='#120a8f', linewidth=linewidth, alpha=1)
line2, = axs[1].plot(x, y2, linestyle='-',
                     color='#8b0000', label='Linearizado', linewidth=linewidth)


axs[1].set_xlabel(r'$\rho$', fontsize=18)
axs[1].set_ylabel('Média dos ITEE (s)', fontsize=16)

axs[1].grid(linestyle='--')
axs[1].set_title('ETM Dinâmico', fontsize=20)
axs[1].tick_params(axis='both', direction='in', length=4, width=1,
                   colors='black', top=True, right=True, labelsize=16)
# Definindo a notação científica para os eixos y
axs[1].ticklabel_format(axis='y', style='sci', scilimits=(-3, 3))


fig.legend([line1, line2], ['Não Linear', 'Linearizado'],
           fontsize=14, loc='upper center', bbox_to_anchor=(.5, 1.3), fancybox=False, shadow=False, ncol=2)

plt.tight_layout()

plt.savefig(
    '/home/andel/Projetos/Latex/[TCC] Andevaldo Vitório/figuras/boost/itee-mean.eps', format='eps', bbox_inches='tight')
# Out:
# /tmp/ipykernel_53721/1915857300.py:55: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Definindo o tamanho da figura e os subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 3.3))

linewidth = 2.

x = [.1, .2, .3, .4, .5, .6, .7, .8, .9]

y1 = [8.580e-03, 9.780e-03, 8.520e-03,
      8.250e-03, 7.420e-03, 7.310e-03, 5.320e-03, 1.016e-02, 4.748e-02]

y2 = [9.770e-03, 7.390e-03, 9.630e-03,
      9.810e-03, 1.052e-02, 1.063e-02, 1.140e-02, 1.009e-02,  4.170e-02]


# Tensão Não Linear
line1, = axs[0].plot(x, y1,
                     linestyle='-', color='#120a8f', linewidth=linewidth, alpha=1)
line2, = axs[0].plot(x, y2, linestyle='-',
                     color='#8b0000', label='Linearizado', linewidth=linewidth)
axs[0].set_xlabel(r'$\rho$', fontsize=18)
axs[0].set_ylabel('$t_{\mathrm{s}}$ (s)', fontsize=18)
axs[0].grid(linestyle='--')
axs[0].set_title('ETM Estático', fontsize=20)
axs[0].tick_params(axis='both', direction='in', length=4, width=1,
                   colors='black', top=True, right=True, labelsize=16)
# axs[0].ticklabel_format(style='plain')


y1 = [8.570e-03, 9.770e-03, 8.510e-03,
      8.250e-03, 7.390e-03, 7.280e-03,  5.350e-03, 1.016e-02,  4.749e-02]

y2 = [9.780e-03, 7.390e-03, 9.630e-03,
      9.820e-03, 1.052e-02, 1.063e-02, 1.140e-02, 1.011e-02, 4.171e-02]


line1, = axs[1].plot(x, y1,
                     linestyle='-', color='#120a8f', linewidth=linewidth, alpha=1)
line2, = axs[1].plot(x, y2, linestyle='-',
                     color='#8b0000', label='Linearizado', linewidth=linewidth)


axs[1].set_xlabel(r'$\rho$', fontsize=18)
axs[1].set_ylabel('$t_{\mathrm{s}}$ (s)', fontsize=18)

axs[1].grid(linestyle='--')
axs[1].set_title('ETM Dinâmico', fontsize=20)
axs[1].tick_params(axis='both', direction='in', length=4, width=1,
                   colors='black', top=True, right=True, labelsize=16)
# axs[1].ticklabel_format(style='plain')


# fig.legend([line1, line2], ['Não Linear', 'Linearizado'],
#            fontsize=18, loc='upper center', bbox_to_anchor=(.5, 0.0), fancybox=False, shadow=False, ncol=2)

plt.tight_layout()

plt.savefig(
    '/home/andel/Projetos/Latex/[TCC] Andevaldo Vitório/figuras/boost/ts.eps', format='eps', bbox_inches='tight')
